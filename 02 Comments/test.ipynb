# %%
# This is the comment.
print("We create a comment using the # symbol.")
print("Multiple lines of code can be commented in R")
# Out:
# [1] "We create a comment using the # symbol."
# [1] "Multiple lines of code can be commented in R"
